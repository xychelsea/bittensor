# %%
import bittensor
import torch 
from transformers import AutoTokenizer
import numpy as np

# %%
logging=bittensor.logging()
dataload = bittensor.dataloader(max_corpus_size=10000)
# Out:
# 2021-09-13 10:55:03.943 |     SUCCESS      | Set debug:          OFF
# 2021-09-13 10:55:03.945 |     SUCCESS      | Set trace:          OFF
# 2021-09-13 10:55:03.945 |     SUCCESS      | Set record log:     OFF

# %%
tokenizer = AutoTokenizer.from_pretrained("gpt2")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2441/1484364116.py in <module>
#       1 tokenizer = AutoTokenizer.from_pretrained("gpt2")
# ----> 2 data_iter = iter(data)
#
# NameError: name 'data' is not defined

# %%
test = next(data_iter)
print(test)
# Out:
# tensor([[ 4480,    45, 12305,    64,  4703,   270,  1169, 16354, 22540,   265,
#             45, 12305,  3791, 49278, 14941, 31810,   261, 16157,  2078,    11],
#         [   45, 12305,    64,  4703,   270,  1169, 16354, 22540,   265,    45,
#          12305,  3791, 49278, 14941, 31810,   261, 16157,  2078,    11, 35411],
#         [42122,    64,  4703,   270,  1169, 16354, 22540,   265,    45, 12305,
#           3791, 49278, 14941, 31810,   261, 16157,  2078,    11, 35411,    13],
#         [   64,  4703,   270,  1169, 16354, 22540,   265,    45, 12305,  3791,
#          49278, 14941, 31810,   261, 16157,  2078,    11, 35411,    13, 15017],
#         [ 4703,   270,  1169, 16354, 22540,   265,    45, 12305,  3791, 49278,
#          14941, 31810,   261, 16157,  2078,    11, 35411,    13, 15017,  3841],
#         [ 1462,  1169, 16354, 22540,   265,    45, 12305,  3791, 49278, 14941,
#          31810,   261, 16157,  2078,    11, 35411,    13, 15017,  3841,  1462],
# ...

# %%
for epoch in np.arange(100):
    print('New Epoch',epoch)
    data = dataload.dataloader(epoch_length=100)
    data_iter = iter(data)
    test = next(data_iter)
    print(test[0])
    decoded = [bittensor.tokenizer().decode(i) for i in test[0]]
    print(decoded)
    test = next(data_iter)
    print(test[0])
    decoded = [bittensor.tokenizer().decode(i) for i in test[0]]
    print(decoded)
    #hugging = tokenizer(decoded)
    #print(len(hugging['input_ids']))
    #print(model(test[j]))
# Out:
# New Epoch 0
# 2021-09-13 10:55:13.823 |     SUCCESS      | Retrieving a dataset files from the IPFS gateway...
# 2021-09-13 10:55:14.309 |     SUCCESS      | Loaded folder:      QmXwfPoh2QFYqC6cYcW8kzyd9ruFfhnUi2kVBkdhawjUzj
# 2021-09-13 10:55:15.269 |     SUCCESS      | Loaded folder:      QmRjFNn3XpYMycVzTE4YcVcxk45vNZcTAjKmtEqPLKwAWd
# 2021-09-13 10:55:15.785 |     SUCCESS      | Downloaded:         Wikitext_KirShara.txt
# 2021-09-13 10:55:15.786 |     SUCCESS      | Saved:              Wikitext_KirShara.txt
# tensor([ 4758, 43439,  1169, 14986,    53,   377,  5171,  1462,  1169,  3041,
#          1161, 15898,  6738,     1,   464, 19857,     1,   261,  2017,  4853])
# ['which', 'saw', 'the', 'original', 'V', 'ul', 'can', 'to', 'the', 'Re', 'formation', 'seen', 'from', '"', 'The', 'Forge', '"', 'on', 'wards', 'equ']
# tensor([   75, 10533, 43764,    51,     6,  8017, 13552,    11,    51,     6,
#         35882,  9908,  7697,     8,    13, 13887, 10755,     1, 23155, 18800])
# ...

# %%
from transformers import AutoModel

model = AutoModel.from_pretrained("bert-base-cased")
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
